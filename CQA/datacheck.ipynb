# %%
import pandas as pd

train_df = pd.read_csv('train.csv')
print(train_df.shape)
train_df.head()
# Out:
# (9741, 3)
#   answerKey                                           question  \
# 0         A  The sanctions against the school were a punish...
# 1         B  Sammy wanted to go to where the people were.  ...
# 2         A  To locate a choker not located in a jewelry bo...
# 3         D  Google Maps and other highway and street GPS s...
# 4         C  The fox walked from the city into the forest, ...
#
#                                              choices
# 0  {'label': array(['A', 'B', 'C', 'D', 'E'], dty...
# 1  {'label': array(['A', 'B', 'C', 'D', 'E'], dty...
# 2  {'label': array(['A', 'B', 'C', 'D', 'E'], dty...
# 3  {'label': array(['A', 'B', 'C', 'D', 'E'], dty...
# 4  {'label': array(['A', 'B', 'C', 'D', 'E'], dty...

# %%
test_df = pd.read_csv('test.csv')
print(test_df.shape)
test_df.head()
# Out:
# (1140, 3)
#    answerKey                                           question  \
# 0        NaN  The townhouse was a hard sell for the realtor,...
# 1        NaN  There is a star at the center of what group of...
# 2        NaN  What were the kids doing as they looked up at ...
# 3        NaN  The person taught an advanced class only for who?
# 4        NaN  What is a likely consequence of ignorance of r...
#
#                                              choices
# 0  {'label': array(['A', 'B', 'C', 'D', 'E'], dty...
# 1  {'label': array(['A', 'B', 'C', 'D', 'E'], dty...
# 2  {'label': array(['A', 'B', 'C', 'D', 'E'], dty...
# 3  {'label': array(['A', 'B', 'C', 'D', 'E'], dty...
# 4  {'label': array(['A', 'B', 'C', 'D', 'E'], dty...

# %%
val_df = pd.read_csv('validation.csv')
print(val_df.shape)
val_df.head()
# Out:
# (1221, 3)
#   answerKey                                           question  \
# 0         A  A revolving door is convenient for two directi...
# 1         A                  What do people aim to do at work?
# 2         B  Where would you find magazines along side many...
# 3         A         Where are  you likely to find a hamburger?
# 4         A  James was looking for a good place to buy farm...
#
#                                              choices
# 0  {'label': array(['A', 'B', 'C', 'D', 'E'], dty...
# 1  {'label': array(['A', 'B', 'C', 'D', 'E'], dty...
# 2  {'label': array(['A', 'B', 'C', 'D', 'E'], dty...
# 3  {'label': array(['A', 'B', 'C', 'D', 'E'], dty...
# 4  {'label': array(['A', 'B', 'C', 'D', 'E'], dty...
